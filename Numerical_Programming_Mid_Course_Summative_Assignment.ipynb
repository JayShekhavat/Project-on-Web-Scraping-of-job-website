# %% [markdown]
# <a href="https://colab.research.google.com/github/JayShekhavat/Project-on-Web-Scraping-of-job-website/blob/main/Numerical_Programming_Mid_Course_Summative_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement: Navigating the Data Science Job Landscape**
#
# 🚀 Unleash your creativity in crafting a solution that taps into the heartbeat of the data science job market! Envision an ingenious project that seamlessly wields cutting-edge web scraping techniques and illuminating data analysis.
#
# 🔍 Your mission? To engineer a tool that effortlessly gathers job listings from a multitude of online sources, extracting pivotal nuggets such as job descriptions, qualifications, locations, and salaries.
#
# 🧩 However, the true puzzle lies in deciphering this trove of data. Can your solution discern patterns that spotlight the most coveted skills? Are there threads connecting job types to compensation packages? How might it predict shifts in industry demand?
#
# 🎯 The core objectives of this challenge are as follows:
#
# 1. Web Scraping Mastery: Forge an adaptable and potent web scraping mechanism. Your creation should adeptly harvest data science job postings from a diverse array of online platforms. Be ready to navigate evolving website structures and process hefty data loads.
#
# 2. Data Symphony: Skillfully distill vital insights from the harvested job listings. Extract and cleanse critical information like job titles, company names, descriptions, qualifications, salaries, locations, and deadlines. Think data refinement and organization.
#
# 3. Market Wizardry: Conjure up analytical tools that conjure meaningful revelations from the gathered data. Dive into the abyss of job demand trends, geographic distribution, salary variations tied to experience and location, favored qualifications, and emerging skill demands.
#
# 4. Visual Magic: Weave a tapestry of visualization magic. Design captivating charts, graphs, and visual representations that paint a crystal-clear picture of the analyzed data. Make these visuals the compass that guides users through job market intricacies.
#
# 🌐 While the web scraping universe is yours to explore, consider these platforms as potential stomping grounds:
#
# * LinkedIn Jobs
# * Indeed
# * Naukri
# * Glassdoor
# * AngelList
#
# 🎈 Your solution should not only decode the data science job realm but also empower professionals, job seekers, and recruiters to harness the dynamic shifts of the industry. The path is open, the challenge beckons – are you ready to embark on this exciting journey?

# %% [markdown]
# ##**Modulary of code**

# %% [markdown]
# #**Scrapping the websites**

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Install the Request and beautifulSoup libraries**

# %%
! pip install beautifulsoup4
! pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %% [markdown]
# Import libraries for web scrapping

# %%
# Import the necessary libraries
import requests
from bs4 import BeautifulSoup
import re
import csv

# %% [markdown]
# ##**Scrapping the Indeed job website**

# %%
# URL of Indeed job search page
url = 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=as&searchTextText=%22Data+Science%22&txtKeywords=%22Data+Science%22&txtLocation='

# Send GET request to the URL
response = requests.get(url)


# Parse HTML content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all job cards
job_cards = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')

print(job_cards)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-hyrefox-consultants-chennai-5-to-8-yrs-jobid-dMBdCrIRA0NzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69115164','data science  ,  data cleaning  ,  dashboards','Chennai','5 - 8','IT Software : Software Products &amp; Services','1','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     HyreFox Consultants
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>5 - 8 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Chennai">Chennai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Must have experience in any programming languageExpertise in data science programming languageResponsible for the design ,  development ,  and maintenance of data pipelinesPer... <a href="https://www.timesjobs.com/job-detail/data-science-hyrefox-consultants-chennai-5-to-8-yrs-jobid-dMBdCrIRA0NzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
# <strong class="blkclor">data</strong> <strong class="blkclor">science</strong>  ,  data cleaning  ,  dashboards
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Chennai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69115164">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('69115164','adId=dMBdCrIRA0NzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','69115164','data science  ,  data cleaning  ,  dashboards','Chennai','5 - 8','IT Software : Software Products &amp; Services','1','as')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 1 day ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-tcg-digital-solutions-pvt-ltd-kolkata-3-to-5-yrs-jobid-XkwEl3YdKG5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','67770544','data analytics  ,  functional analysis  ,  predictive analytics  ,  data science  ,  solution design','Kolkata','3 - 5','IT Software : Software Products &amp; Services','2','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     tcg digital solutions pvt ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>3 - 5 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Kolkata">Kolkata</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Education Masters / Bachelors degree in Computer Science or equivalent /  Statistics /  Data Science. ( Candidates from tier 1 institute or tier 1 consultancy organizations ar... <a href="https://www.timesjobs.com/job-detail/data-science-tcg-digital-solutions-pvt-ltd-kolkata-3-to-5-yrs-jobid-XkwEl3YdKG5zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           data analytics  ,  functional analysis  ,  predictive analytics  ,  <strong class="blkclor">data</strong> <strong class="blkclor">science</strong>  ,  solution design
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Kolkata
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_67770544">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('67770544','adId=XkwEl3YdKG5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','67770544','data analytics  ,  functional analysis  ,  predictive analytics  ,  data science  ,  solution design','Kolkata','3 - 5','IT Software : Software Products &amp; Services','2','as')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-innefu-labs-pvt-ltd-delhi-delhi-ncr-4-to-6-yrs-jobid-__SLASH__w71YxGI__SLASH__cxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69384002','procedures  ,  data collection  ,   Commercial activities','Delhi,  Delhi/NCR','4 - 6','IT Software : Software Products &amp; Services','3','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     innefu labs pvt. ltd.
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>4 - 6 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Delhi,  Delhi/NCR">Delhi,  Delhi/NCR</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Location : DelhiDescriptions :4-6 YearsUsing machine learning tools to select features ,  create and optimize classifiersCarrying out preprocessing of structured and unstructu... <a href="https://www.timesjobs.com/job-detail/data-science-innefu-labs-pvt-ltd-delhi-delhi-ncr-4-to-6-yrs-jobid-__SLASH__w71YxGI__SLASH__cxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           procedures  ,  data collection  ,   Commercial activities
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Delhi,  Delhi/NCR
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69384002">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('69384002','adId=__SLASH__w71YxGI__SLASH__cxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','69384002','procedures  ,  data collection  ,   Commercial activities','Delhi,  Delhi/NCR','4 - 6','IT Software : Software Products &amp; Services','3','as')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-bprise-pvt-ltd-mumbai-3-to-6-yrs-jobid-ruGxeZWDUItzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','66865297','hive  ,  algorithms  ,  authoring  ,  data mining  ,  sql  ,  pig  ,  d3.js  ,  security  ,  java  ,  big data  ,  mongodb  ,  hbase  ,  python  ,  machine learning  ,  nosql  ,  cassandra','Mumbai','3 - 6','IT Software : Software Products &amp; Services','4','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     bprise pvt ltd
#
#     </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>3 - 6 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Mumbai">Mumbai</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Develop and plan required analytic projects in response to business needs.Partner with Product and Engineering teams to solve problems and identify trends and opportunities.pr... <a href="https://www.timesjobs.com/job-detail/data-science-bprise-pvt-ltd-mumbai-3-to-6-yrs-jobid-ruGxeZWDUItzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           hive  ,  algorithms  ,  authoring  ,  data mining  ,  sql  ,  pig  ,  d3.js  ,  security  ,  java  ,  big data  ,  mongodb  ,  hbase  ,  python  ,  machine learning  ,  nosql  ,  cassandra
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Mumbai
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_66865297">
# <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('66865297','adId=ruGxeZWDUItzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','66865297','hive  ,  algorithms  ,  authoring  ,  data mining  ,  sql  ,  pig  ,  d3.js  ,  security  ,  java  ,  big data  ,  mongodb  ,  hbase  ,  python  ,  machine learning  ,  nosql  ,  cassandra','Mumbai','3 - 6','IT Software : Software Products &amp; Services','4','as')">Apply</a>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-iL6jXjsJ6fxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69807759','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','5','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies Pvt Ltd is it company based in ahmedabad. we are offering an internship in data science and machine learning  , why interns choosing us ?friendly work cult... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-iL6jXjsJ6fxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="10-Feb-2024 - 10-Apr-2024 | 09:30 AM - 03:30 PM | 303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad"><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 10-Feb-2024 - 10-Apr-2024 <span class="round-sep"></span> 09:30 AM - 03:30 PM <span class="round-sep"></span>  303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69807759">
# <button class="waves-effect waves-light btn" id="apply_69807759" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69807759','INT','TJPFSRP');logViewUSBT('apply','69807759','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','5','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 3 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-sWhOwQZdqVRzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69798282','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','6','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies Pvt Ltd is it company based in ahmedabad. we are offering an internship in data science and machine learning program.why interns choosing us ?friendly work... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-sWhOwQZdqVRzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="01-Feb-2024 - 01-Apr-2024 | 09:00 AM - 04:00 PM | 303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad"><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 01-Feb-2024 - 01-Apr-2024 <span class="round-sep"></span> 09:00 AM - 04:00 PM <span class="round-sep"></span>  303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69798282">
# <button class="waves-effect waves-light btn" id="apply_69798282" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69798282','INT','TJPFSRP');logViewUSBT('apply','69798282','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','6','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
#        <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-llm-ltimindtree-bengaluru-bangalore-chennai-hyderabad-secunderabad-mumbai-pune-7-to-12-yrs-jobid-BdXZX6EOQaFzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69797327','LLM  ,  Large language model  ,  Datascience  ,  azure  ,  data scientist  ,  datascientist','Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune','7 - 12','IT Hardware : Hardware Products &amp; Services,  IT Software : Software Products &amp; Services','7','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong>-LLM</a> </h2>
# <h3 class="joblist-comp-name">
#     LTIMindtree Ltd.
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=8NqVm__PLUS__d__PLUS__eSBzpSvf__PLUS__uAgZw==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>7 - 12 yrs</li>
# <li><i class="material-icons rupee">₹</i>Rs 15.00 - 35.00 Lacs p.a.</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune">Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# 8+ years of IT experience and minimum of 5+ years of experience on Azure Open AI ,  Cognitive services ,  Cognitive Search ,  Azure Open AI Embedding Models - text-embedding-a... <a href="https://www.timesjobs.com/job-detail/data-science-llm-ltimindtree-bengaluru-bangalore-chennai-hyderabad-secunderabad-mumbai-pune-7-to-12-yrs-jobid-BdXZX6EOQaFzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           LLM  ,  "Large language model"  ,  Datascience  ,  azure  ,  "data scientist"  ,  datascientist
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69797327">
# <button class="waves-effect waves-light btn" id="apply_69797327" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('69797327','INT','TJPFSRP');logViewUSBT('apply','69797327','LLM  ,  Large language model  ,  Datascience  ,  azure  ,  data scientist  ,  datascientist','Bengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune','7 - 12','IT Hardware : Hardware Products &amp; Services,  IT Software : Software Products &amp; Services','7','as')">Apply</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-HS3FPYHHL5RzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69791665','.','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','8','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana">Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offers live project internship ahmedabad .we are offering internships in core python  , django and machine learning .why maxgen?hybrid internship. ... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-HS3FPYHHL5RzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69791665">
# <button class="waves-effect waves-light btn" id="apply_69791665" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('69791665','INT','TJPFSRP');logViewUSBT('apply','69791665','.','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','8','as')">Apply</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-Ru3ljS__SLASH__rFQdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69790888','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','9','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Pune</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offering live project web development internship in pune. we are offering internships in data science and machine learning .benefit to join us ?col... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-Ru3ljS__SLASH__rFQdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="21-Jan-2024 - 18-Mar-2024 | 11:00 AM - 04:00 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 21-Jan-2024 - 18-Mar-2024 <span class="round-sep"></span> 11:00 AM - 04:00 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69790888">
# <button class="waves-effect waves-light btn" id="apply_69790888" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69790888','INT','TJPFSRP');logViewUSBT('apply','69790888','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','9','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-kA37dWHJHaZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69790197','ml','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','10','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship In Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies Pvt Ltd is it company based in ahmedabad. we are offering an internship in data science and data scientist.why interns choosing us ?friendly work culture. ... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-kA37dWHJHaZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           ml
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="19-Jan-2024 - 15-Mar-2024 | 09:00 AM - 05:00 PM | 303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad"><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 19-Jan-2024 - 15-Mar-2024 <span class="round-sep"></span> 09:00 AM - 05:00 PM <span class="round-sep"></span>  303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69790197">
# <button class="waves-effect waves-light btn" id="apply_69790197" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69790197','INT','TJPFSRP');logViewUSBT('apply','69790197','ml','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','10','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-3Y8FIez9oYpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69788743','.','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','11','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship In Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana">Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offers live project internship ahmedabad .we are offering internships in data science and machine learning program.what we offer ?hybrid internship... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-3Y8FIez9oYpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69788743">
# <button class="waves-effect waves-light btn" id="apply_69788743" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('69788743','INT','TJPFSRP');logViewUSBT('apply','69788743','.','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','11','as')">Apply</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-k5x61gNtTbhzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69787891','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','12','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen technologies pvt ltd offering live project internship in ahmedabad. we are offering internships in data science  ,  machine learning. why interns choosing us ?basic to ... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-k5x61gNtTbhzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="12-Jan-2024 - 11-Mar-2024 | 10:30 AM - 05:00 PM | 303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad"><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 12-Jan-2024 - 11-Mar-2024 <span class="round-sep"></span> 10:30 AM - 05:00 PM <span class="round-sep"></span>  303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69787891">
# <button class="waves-effect waves-light btn" id="apply_69787891" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69787891','INT','TJPFSRP');logViewUSBT('apply','69787891','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','12','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted a month ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-classroom-trainer-naresh-i-technologies-hyderabad-secunderabad-5-to-10-yrs-jobid-zWPzv55rpTpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69774145','ML  ,  DL  ,  R Programming  ,  Python  ,  Machine learning  ,  Deep Learning','Hyderabad/Secunderabad','5 - 10','Education / Teaching / Language Specialist,  IT Software : Software Products &amp; Services','13','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Classroom Trainer</a> </h2>
# <h3 class="joblist-comp-name">
#     NARESH I TECHNOLOGIES
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=dRV6Bow6LlnbKK03ofgCFg==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>5 - 10 yrs</li>
# <li><i class="material-icons rupee">₹</i>Rs 5.00 - 10.00 Lacs p.a.</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Hyderabad/Secunderabad">Hyderabad/Secunderabad</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Designation / Position - Data Science Classroom TrainerShould have a good knowledge of Machine learning  ,  Deep Learning ,  R Programming; Python , Statistics , Hadoop etc. U... <a href="https://www.timesjobs.com/job-detail/data-science-classroom-trainer-naresh-i-technologies-hyderabad-secunderabad-5-to-10-yrs-jobid-zWPzv55rpTpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           ML  ,  DL  ,  R Programming  ,  Python  ,  Machine learning  ,  Deep Learning
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Hyderabad/Secunderabad
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69774145">
# <button class="waves-effect waves-light btn" id="apply_69774145" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('69774145','INT','TJPFSRP');logViewUSBT('apply','69774145','ML  ,  DL  ,  R Programming  ,  Python  ,  Machine learning  ,  Deep Learning','Hyderabad/Secunderabad','5 - 10','Education / Teaching / Language Specialist,  IT Software : Software Products &amp; Services','13','as')">Apply</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-OSlmr00hTHJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69784290','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','14','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offers live project internships in Ahmedabad. We are offering internships in the data science  , Machine leraning and ai.what do we offer?hybrid in... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-mehsana-rajkot-surat-surendranagar-0-to-1-yrs-jobid-OSlmr00hTHJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="31-Dec-2023 - 28-Feb-2024 | 09:30 AM - 05:00 PM | 303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad"><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 31-Dec-2023 - 28-Feb-2024 <span class="round-sep"></span> 09:30 AM - 05:00 PM <span class="round-sep"></span>  303 shoppers plaza 4, Chimanlal Girdharlal Rd, Ahmedabad</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69784290">
# <button class="waves-effect waves-light btn" id="apply_69784290" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69784290','INT','TJPFSRP');logViewUSBT('apply','69784290','.','Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar','0 - 1','IT Software : Software Products &amp; Services','14','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted a month ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-Mu2yU2gspdxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69785814','software development','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','15','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana">Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies Pvt ltd offers live project internships in ahmedabad. We are offering an internship in data science and machine learning.why are interns choosing us?friend... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-Mu2yU2gspdxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           software development
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69785814">
# <button class="waves-effect waves-light btn" id="apply_69785814" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('69785814','INT','TJPFSRP');logViewUSBT('apply','69785814','software development','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','15','as')">Apply</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted a month ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-QL9DJ52O9nNzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69782516','.','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','16','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Ahmedabad</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana">Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies Pvt ltd offers live project internships in ahmedabad. We are offering an internship in data science.why are interns choosing us?friendly work culture.smoot... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-ahmedabad-maxgen-technologies-ahmedabad-bhavnagar-gandhinagar-jamnagar-mehsana-0-to-1-yrs-jobid-QL9DJ52O9nNzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <!--
#             <li>
#               <i class="material-icons">location_on</i>
#               Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana
#               </li>
# -->
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69782516">
# <button class="waves-effect waves-light btn" id="apply_69782516" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_others');jobSRPApplyFuncInline('69782516','INT','TJPFSRP');logViewUSBT('apply','69782516','.','Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana','0 - 1','IT Software : Software Products &amp; Services','16','as')">Apply</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted a month ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-p1KmEzbK9MNzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69807756','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','17','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship In Pune</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen technologies pvt ltd offering college project internship in pune . internship we are offering in data science and machine learning .what we are offering?available for o... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-p1KmEzbK9MNzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="10-Feb-2024 - 10-Apr-2024 | 11:00 AM - 04:00 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 10-Feb-2024 - 10-Apr-2024 <span class="round-sep"></span> 11:00 AM - 04:00 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69807756">
# <button class="waves-effect waves-light btn" id="apply_69807756" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69807756','INT','TJPFSRP');logViewUSBT('apply','69807756','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','17','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted 3 days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-JOsiXA45gbVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69800234','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','18','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Pune</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen technologies pvt ltd offers live project internships in pune. we are offering internships in data science and machien learning .why we are important ?hybrid programme. ... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-JOsiXA45gbVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="06-Feb-2024 - 05-Apr-2024 | 10:30 AM - 05:30 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# ...
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offering live project internship in pune. we are offering internships in data science and machine learning program.why we are best for an internshi... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-PhmIOuJkHKhzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="16-Jan-2024 - 15-Mar-2024 | 09:30 AM - 04:00 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 16-Jan-2024 - 15-Mar-2024 <span class="round-sep"></span> 09:30 AM - 04:00 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69788746">
# <button class="waves-effect waves-light btn" id="apply_69788746" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69788746','INT','TJPFSRP');logViewUSBT('apply','69788746','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','20','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-yWVGLrik7fVzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69790889','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','21','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Pune</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offering live project web development internship in pune. we are offering internships in data science and machine learning .benefit to join us ?col... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-yWVGLrik7fVzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="21-Jan-2024 - 18-Mar-2024 | 11:00 AM - 04:00 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 21-Jan-2024 - 18-Mar-2024 <span class="round-sep"></span> 11:00 AM - 04:00 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69790889">
# <button class="waves-effect waves-light btn" id="apply_69790889" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69790889','INT','TJPFSRP');logViewUSBT('apply','69790889','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','21','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-ECji7JQg86JzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69788287','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','22','as' )" target="_blank">
# <strong class="blkclor">DATA</strong> <strong class="blkclor">SCIENCE</strong> INTERNSHIP IN PUNE</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li><i class="material-icons rupee">₹</i>Rs 1.00 - 2.00 Lacs p.a.</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offering live project internship in pune. we are offering internships in data science and data scientist program.why we are best for an internship ... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-ECji7JQg86JzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="14-Jan-2024 - 12-Mar-2024 | 09:00 AM - 04:30 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 14-Jan-2024 - 12-Mar-2024 <span class="round-sep"></span> 09:00 AM - 04:30 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69788287">
# <button class="waves-effect waves-light btn" id="apply_69788287" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69788287','INT','TJPFSRP');logViewUSBT('apply','69788287','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','22','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-AHxKN8p5UihzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69796816','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','23','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Pune</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offering live project web development internship in pune. we are offering internships in data science and machine learning .benefit to join us ?col... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-AHxKN8p5UihzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="29-Jan-2024 - 27-Mar-2024 | 09:30 AM - 04:30 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 29-Jan-2024 - 27-Mar-2024 <span class="round-sep"></span> 09:30 AM - 04:30 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69796816">
# <button class="waves-effect waves-light btn" id="apply_69796816" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69796816','INT','TJPFSRP');logViewUSBT('apply','69796816','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','23','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-Agt6o5KydV5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69790202','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','24','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship In Pune</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offering live project software development internship in pune. we are offering internships in data science  , data scientist. benefit to join us ?c... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-Agt6o5KydV5zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="19-Jan-2024 - 15-Mar-2024 | 11:00 AM - 04:00 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 19-Jan-2024 - 15-Mar-2024 <span class="round-sep"></span> 11:00 AM - 04:00 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69790202">
# <button class="waves-effect waves-light btn" id="apply_69790202" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69790202','INT','TJPFSRP');logViewUSBT('apply','69790202','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','24','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted few days ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>, <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-labRRDgi605zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69787895','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','25','as' )" target="_blank">
# <strong class="blkclor">Data</strong> <strong class="blkclor">Science</strong> Internship in Pune</a> </h2>
# <h3 class="joblist-comp-name">
#     Maxgen Technologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=GXSvsub08IAxd9pert2qGQ==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
# <li><i class="material-icons rupee">₹</i>Rs 1.00 - 2.00 Lacs p.a.</li>
# <li>
# <i class="material-icons">location_on</i>
# <span title="Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur">Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur</span>
# </li>
# </ul>
# <ul class="list-job-dtl clearfix">
# <li>
# <label>Job Description:</label>
# Maxgen Technologies pvt ltd offering live project internship in pune. we are offering internships in data science and data scientist programs. why we are best for an internshi... <a href="https://www.timesjobs.com/job-detail/data-science-internship-in-pune-maxgen-technologies-pune-jalgaon-kolhapur-nagpur-solapur-0-to-1-yrs-jobid-labRRDgi605zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
# </li>
# <li>
# <label>KeySkills:</label>
# <span class="srp-skills">
#
#           .
#
#       </span> </li>
# <li class="srp-walkin-dtl"><span class="clearfix" title="12-Jan-2024 - 09-Mar-2024 | 09:00 AM - 03:30 PM | 509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune."><i class="material-icons">directions_walk</i>
# <label>Walk-in Details</label> 12-Jan-2024 - 09-Mar-2024 <span class="round-sep"></span> 09:00 AM - 03:30 PM <span class="round-sep"></span>  509 , 5th Floor, Pride Icon, Kharadi, Near Atithi Veg Restaurant Pune.</span></li>
# </ul>
# <div class="list-job-bt clearfix">
# <div class="list-action">
# <div class="applied-dtl clearfix" id="showPostApplyData_69787895">
# <button class="waves-effect waves-light btn" id="apply_69787895" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_walkinType');jobSRPApplyFuncInline('69787895','INT','TJPFSRP');logViewUSBT('apply','69787895','.','Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur','0 - 1','IT Software : Software Products &amp; Services','25','as')">Show Interest</button>
# <span class="jobs-status clearfix">
# <!--
# -->
# </span>
# <span class="sim-posted">
# <span>Posted a month ago</span>
# </span>
# </div>
# </div>
# </div>
# </li>]

# %%
lst = soup.find('ul', class_="top-jd-dtl clearfix")

# %%
lst1 = soup.find('li',class_="clearfix job-bx wht-shd-bx")

# %%
print(lst1.text.strip())
# Out:
# Data Science
#
#     HyreFox Consultants
#
#
#
#
# card_travel5 - 8 yrs
#
# location_on
# Chennai
#
#
#
#
# Job Description:
# Must have experience in any programming languageExpertise in data science programming languageResponsible for the design ,  development ,  and maintenance of data pipelinesPer... More Details
#
#
# KeySkills:
#
# data science  ,  data cleaning  ,  dashboards
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted 1 day ago

# %%
print(lst.text.strip())
# Out:
# card_travel5 - 8 yrs
#
# location_on
# Chennai

# %%
print(lst.text.strip().split('-')[1])
# Out:
#  8 yrs
#
# location_on
# Chennai

# %%
print(lst.text.strip().split('-')[1].split('\n'))
# Out:
# [' 8 yrs', '', 'location_on', 'Chennai']

# %%
print(lst.text.strip().split('-')[1].split('\n')[0])
# Out:
#  8 yrs

# %%
print(lst.text.strip().split('-')[1].split('\n')[3:])
# Out:
# ['Chennai']

# %%
lst = soup.find('ul', class_="list-job-dtl clearfix")

# %%
print(lst.text.strip())
# Out:
# Job Description:
# Must have experience in any programming languageExpertise in data science programming languageResponsible for the design ,  development ,  and maintenance of data pipelinesPer... More Details
#
#
# KeySkills:
#
# data science  ,  data cleaning  ,  dashboards

# %%
print(lst.text.strip().split(':')[1].split('\n')[1])
# Out:
# Must have experience in any programming languageExpertise in data science programming languageResponsible for the design ,  development ,  and maintenance of data pipelinesPer... More Details

# %%
print(lst.text.strip().split(':')[2].split('\n')[2:])
# Out:
# ['data science  ,  data cleaning  ,  dashboards']

# %%
print(lst.text.strip().split(':')[1:])
# Out:
# ['\r\nMust have experience in any programming languageExpertise in data science programming languageResponsible for the design ,  development ,  and maintenance of data pipelinesPer... More Details\n\n\nKeySkills', '\n\ndata science  ,  data cleaning  ,  dashboards']

# %%
job_title = []
company_name = []
job_description = []
skills = []
location = []
experience = []


for i in job_cards:
  job_title.append(i.find('h2').text.strip())
  company_name.append(i.find('h3', class_="joblist-comp-name").text.strip())
  job_description.append(i.find('ul', class_ = "list-job-dtl clearfix").text.strip().split(':')[1].split('\n')[1])
  skills.append(i.find('ul', class_ = "list-job-dtl clearfix").text.strip().split(':')[2].split('\n')[2:])
  experience.append(i.find('ul', class_="top-jd-dtl clearfix").text.strip().split('-')[1].split('\n')[0])
  location.append(i.find('ul', class_="top-jd-dtl clearfix").text.strip().split('-')[1].split('\n')[3:])


dicts = {'job_title':job_title, 'company_name':company_name, 'job_description':job_description, 'skills':skills, 'experience':experience,'location':location}

df = pd.DataFrame(dicts)

# %%
df.head(9)
# Out:
#                               job_title  \
# 0                          Data Science
# 1                          Data Science
# 2                          Data Science
# 3                          Data Science
# 4  Data Science Internship in Ahmedabad
# 5  Data Science Internship in Ahmedabad
# 6                      Data Science-LLM
# 7  Data Science Internship in Ahmedabad
# 8       Data Science Internship in Pune
#
#                               company_name  \
# 0                      HyreFox Consultants
# 1            tcg digital solutions pvt ltd
# 2                    innefu labs pvt. ltd.
# 3                           bprise pvt ltd
# 4  Maxgen Technologies\r\n     (More Jobs)
# 5  Maxgen Technologies\r\n     (More Jobs)
# 6     LTIMindtree Ltd.\r\n     (More Jobs)
# 7  Maxgen Technologies\r\n     (More Jobs)
# 8  Maxgen Technologies\r\n     (More Jobs)
#
#                                      job_description  \
# 0  Must have experience in any programming langua...
# 1  Education Masters / Bachelors degree in Comput...
# 2                                          Location
# 3  Develop and plan required analytic projects in...
# 4  Maxgen Technologies Pvt Ltd is it company base...
# 5  Maxgen Technologies Pvt Ltd is it company base...
# 6  8+ years of IT experience and minimum of 5+ ye...
# 7  Maxgen Technologies pvt ltd offers live projec...
# 8  Maxgen Technologies pvt ltd offering live proj...
#
#                                               skills experience  \
# 0    [data science  ,  data cleaning  ,  dashboards]      8 yrs
# 1  [      \r,           data analytics  ,  functi...      5 yrs
# 2                                                 []      6 yrs
# 3  [      \r,           hive  ,  algorithms  ,  a...      6 yrs
# 4  [      \r,           .\r,         \r,        ,...      1 yrs
# 5  [      \r,           .\r,         \r,        ,...      1 yrs
# 6  [      \r,           LLM  ,  "Large language m...     12 yrs
# 7                            [      \r,           .]      1 yrs
# 8  [      \r,           .\r,         \r,        ,...      1 yrs
#
#                                             location
# 0                                          [Chennai]
# 1                                          [Kolkata]
# 2                                [Delhi,  Delhi/NCR]
# 3                                           [Mumbai]
# 4  [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...
# 5  [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...
# 6                                                 []
# 7  [Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnaga...
# 8     [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]

# %%
df.shape
# Out:
# (25, 6)

# %%
df.isnull().sum()
# Out:
# job_title          0
# company_name       0
# job_description    0
# skills             0
# salary             0
# location           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['job_title', 'company_name', 'job_description', 'skills', 'experience',
#        'location'],
#       dtype='object')

# %%
df['job_title'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                             Data Science
# 1                             Data Science
# 2                             Data Science
# 3                             Data Science
# 4     Data Science Internship in Ahmedabad
# 5     Data Science Internship in Ahmedabad
# 6                         Data Science-LLM
# 7     Data Science Internship in Ahmedabad
# 8          Data Science Internship in Pune
# 9     Data Science Internship In Ahmedabad
# 10    Data Science Internship In Ahmedabad
# 11    Data Science Internship in Ahmedabad
# 12          Data Science Classroom Trainer
# 13    Data Science Internship in Ahmedabad
# 14    Data Science Internship in Ahmedabad
# 15    Data Science Internship in Ahmedabad
# 16         Data Science Internship In Pune
# 17         Data Science Internship in Pune
# 18         Data Science Internship In Pune
# 19         Data Science Internship In Pune
# 20         Data Science Internship in Pune
# 21         DATA SCIENCE INTERNSHIP IN PUNE
# 22         Data Science Internship in Pune
# 23         Data Science Internship In Pune
# 24         Data Science Internship in Pune
# Name: job_title, dtype: object>

# %%
df['company_name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                           HyreFox Consultants
# 1                 tcg digital solutions pvt ltd
# 2                         innefu labs pvt. ltd.
# 3                                bprise pvt ltd
# 4       Maxgen Technologies\r\n     (More Jobs)
# 5       Maxgen Technologies\r\n     (More Jobs)
# 6          LTIMindtree Ltd.\r\n     (More Jobs)
# 7       Maxgen Technologies\r\n     (More Jobs)
# 8       Maxgen Technologies\r\n     (More Jobs)
# 9       Maxgen Technologies\r\n     (More Jobs)
# 10      Maxgen Technologies\r\n     (More Jobs)
# 11      Maxgen Technologies\r\n     (More Jobs)
# 12    NARESH I TECHNOLOGIES\r\n     (More Jobs)
# 13      Maxgen Technologies\r\n     (More Jobs)
# 14      Maxgen Technologies\r\n     (More Jobs)
# 15      Maxgen Technologies\r\n     (More Jobs)
# 16      Maxgen Technologies\r\n     (More Jobs)
# 17      Maxgen Technologies\r\n     (More Jobs)
# 18      Maxgen Technologies\r\n     (More Jobs)
# 19      Maxgen Technologies\r\n     (More Jobs)
# 20      Maxgen Technologies\r\n     (More Jobs)
# 21      Maxgen Technologies\r\n     (More Jobs)
# 22      Maxgen Technologies\r\n     (More Jobs)
# 23      Maxgen Technologies\r\n     (More Jobs)
# 24      Maxgen Technologies\r\n     (More Jobs)
# Name: company_name, dtype: object>

# %%
df['job_description'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     Must have experience in any programming langua...
# 1     Education Masters / Bachelors degree in Comput...
# 2                                             Location
# 3     Develop and plan required analytic projects in...
# 4     Maxgen Technologies Pvt Ltd is it company base...
# 5     Maxgen Technologies Pvt Ltd is it company base...
# 6     8+ years of IT experience and minimum of 5+ ye...
# 7     Maxgen Technologies pvt ltd offers live projec...
# 8     Maxgen Technologies pvt ltd offering live proj...
# 9     Maxgen Technologies Pvt Ltd is it company base...
# 10    Maxgen Technologies pvt ltd offers live projec...
# 11    Maxgen technologies pvt ltd offering live proj...
# 12    Designation / Position - Data Science Classroo...
# 13    Maxgen Technologies pvt ltd offers live projec...
# 14    Maxgen Technologies Pvt ltd offers live projec...
# 15    Maxgen Technologies Pvt ltd offers live projec...
# 16    Maxgen technologies pvt ltd offering college p...
# 17    Maxgen technologies pvt ltd offers live projec...
# 18    Maxgen Technologies pvt ltd offering live proj...
# 19    Maxgen Technologies pvt ltd offering live proj...
# 20    Maxgen Technologies pvt ltd offering live proj...
# 21    Maxgen Technologies pvt ltd offering live proj...
# 22    Maxgen Technologies pvt ltd offering live proj...
# 23    Maxgen Technologies pvt ltd offering live proj...
# 24    Maxgen Technologies pvt ltd offering live proj...
# Name: job_description, dtype: object>

# %%
df['experience'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       8 yrs
# 1       5 yrs
# 2       6 yrs
# 3       6 yrs
# 4       1 yrs
# 5       1 yrs
# 6      12 yrs
# 7       1 yrs
# 8       1 yrs
# 9       1 yrs
# 10      1 yrs
# 11      1 yrs
# 12     10 yrs
# 13      1 yrs
# 14      1 yrs
# 15      1 yrs
# 16      1 yrs
# 17      1 yrs
# 18      1 yrs
# 19      1 yrs
# 20      1 yrs
# 21      1 yrs
# 22      1 yrs
# 23      1 yrs
# 24      1 yrs
# Name: experience, dtype: object>

# %%
df['location'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                             [Chennai]
# 1                                             [Kolkata]
# 2                                   [Delhi,  Delhi/NCR]
# 3                                              [Mumbai]
# 4     [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...
# 5     [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...
# 6                                                    []
# 7     [Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnaga...
# 8        [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]
# 9     [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...
# 10    [Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnaga...
# 11    [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...
# 12                                                   []
# 13    [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...
# 14    [Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnaga...
# 15    [Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnaga...
# 16       [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]
# 17       [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]
# 18       [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]
# 19                                                   []
# 20       [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]
# 21                                                   []
# 22       [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]
# 23       [Pune,  Jalgaon,  Kolhapur,  Nagpur,  Solapur]
# 24                                                   []
# Name: location, dtype: object>

# %%
df.drop('skills',axis = 1,  inplace  = True)

# %%
df.head()
# Out:
#                               job_title  \
# 0                          Data Science
# 1                          Data Science
# 2                          Data Science
# 3                          Data Science
# 4  Data Science Internship in Ahmedabad
#
#                               company_name  \
# 0                      HyreFox Consultants
# 1            tcg digital solutions pvt ltd
# 2                    innefu labs pvt. ltd.
# 3                           bprise pvt ltd
# 4  Maxgen Technologies\r\n     (More Jobs)
#
#                                      job_description experience  \
# 0  Must have experience in any programming langua...      8 yrs
# 1  Education Masters / Bachelors degree in Comput...      5 yrs
# 2                                          Location       6 yrs
# 3  Develop and plan required analytic projects in...      6 yrs
# 4  Maxgen Technologies Pvt Ltd is it company base...      1 yrs
#
#                                             location
# 0                                          [Chennai]
# 1                                          [Kolkata]
# 2                                [Delhi,  Delhi/NCR]
# 3                                           [Mumbai]
# 4  [Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surend...

# %%
#saving filter data as Filter Data in csv format
df.to_csv('Jobs Data.csv',index=False)

# %% [markdown]
# ##**Summary and Technical document**

# %% [markdown]
# I Extracted data from https://www.timesjobs.com website, fetched top data science jobs from timejobs website.
# There are 25 records and 6 columns in final dataset.
# Most jobs are from data science and data analysis.
# For all jobs need experience to apply examination form.
